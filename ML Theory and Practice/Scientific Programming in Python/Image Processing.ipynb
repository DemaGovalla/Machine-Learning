# %%
# Read an plot a .jpg file

import numpy as np
import matplotlib.pyplot as plt

img = plt.imread('motorbike.jpg')
plt.imshow(img)
img.shape
# Out:
# (3456, 5184, 3)

# %%
img = plt.imread('red_dot_small.png'); 
img = img[:8 ,:8 ,:3]
plt.imshow(img)
img.shape
# Out:
# (8, 8, 3)

# %%
img[200 ,250 ,1]=0; img[200 ,250 ,2]=0
plt.imshow(img)
